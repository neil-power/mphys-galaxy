# %%
import torchvision.models as models
from torchinfo import summary
from custom_models.G_ResNet_18 import G_ResNet18
from custom_models.Jia_ResNet import JiaResnet50
from custom_models.LeNet import VanillaLeNet
from custom_models.Steerable_LeNet import CNSteerableLeNet

# %%
model_versions = {
        "resnet18": models.resnet18,
        "resnet50": models.resnet50,
        "jiaresnet50": JiaResnet50,
        "g_resnet18": G_ResNet18,
        "lenet": VanillaLeNet,
        "g_lenet": CNSteerableLeNet
    }
batch_size = 100
image_size = 160
num_channels = 3

def summarise(model_name):
    model = model_versions[model_name]()
    summary(model, input_size=(batch_size, num_channels, image_size, image_size), col_names=["input_size", "output_size", "kernel_size"],verbose=1)

# %% [markdown]
# ## LeNet

# %%
summarise('lenet')
# Out:
# ===================================================================================================================
# Layer (type:depth-idx)                   Input Shape               Output Shape              Kernel Shape
# ===================================================================================================================
# VanillaLeNet                             [100, 3, 160, 160]        [100, 3]                  --
# ├─Conv2d: 1-1                            [100, 3, 160, 160]        [100, 6, 158, 158]        [5, 5]
# ├─Conv2d: 1-2                            [100, 6, 79, 79]          [100, 16, 77, 77]         [5, 5]
# ├─Linear: 1-3                            [100, 23104]              [100, 120]                --
# ├─Linear: 1-4                            [100, 120]                [100, 84]                 --
# ├─Dropout: 1-5                           [100, 84]                 [100, 84]                 --
# ├─Linear: 1-6                            [100, 84]                 [100, 3]                  --
# ===================================================================================================================
# Total params: 2,785,891
# Trainable params: 2,785,891
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 2.85
# ===================================================================================================================
# Input size (MB): 30.72
# Forward/backward pass size (MB): 195.88
# Params size (MB): 11.14
# Estimated Total Size (MB): 237.75
# ===================================================================================================================

# %% [markdown]
# ## G_LeNet

# %%
#summarise('g_lenet')

# %% [markdown]
# ## Resnet18

# %%
summarise('resnet18')
# Out:
# ===================================================================================================================
# Layer (type:depth-idx)                   Input Shape               Output Shape              Kernel Shape
# ===================================================================================================================
# ResNet                                   [100, 3, 160, 160]        [100, 1000]               --
# ├─Conv2d: 1-1                            [100, 3, 160, 160]        [100, 64, 80, 80]         [7, 7]
# ├─BatchNorm2d: 1-2                       [100, 64, 80, 80]         [100, 64, 80, 80]         --
# ├─ReLU: 1-3                              [100, 64, 80, 80]         [100, 64, 80, 80]         --
# ├─MaxPool2d: 1-4                         [100, 64, 80, 80]         [100, 64, 40, 40]         3
# ├─Sequential: 1-5                        [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    └─BasicBlock: 2-1                   [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─Conv2d: 3-1                  [100, 64, 40, 40]         [100, 64, 40, 40]         [3, 3]
# │    │    └─BatchNorm2d: 3-2             [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─ReLU: 3-3                    [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─Conv2d: 3-4                  [100, 64, 40, 40]         [100, 64, 40, 40]         [3, 3]
# │    │    └─BatchNorm2d: 3-5             [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─ReLU: 3-6                    [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    └─BasicBlock: 2-2                   [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─Conv2d: 3-7                  [100, 64, 40, 40]         [100, 64, 40, 40]         [3, 3]
# │    │    └─BatchNorm2d: 3-8             [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─ReLU: 3-9                    [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─Conv2d: 3-10                 [100, 64, 40, 40]         [100, 64, 40, 40]         [3, 3]
# │    │    └─BatchNorm2d: 3-11            [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─ReLU: 3-12                   [100, 64, 40, 40]         [100, 64, 40, 40]         --
# ├─Sequential: 1-6                        [100, 64, 40, 40]         [100, 128, 20, 20]        --
# │    └─BasicBlock: 2-3                   [100, 64, 40, 40]         [100, 128, 20, 20]        --
# │    │    └─Conv2d: 3-13                 [100, 64, 40, 40]         [100, 128, 20, 20]        [3, 3]
# │    │    └─BatchNorm2d: 3-14            [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─ReLU: 3-15                   [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─Conv2d: 3-16                 [100, 128, 20, 20]        [100, 128, 20, 20]        [3, 3]
# │    │    └─BatchNorm2d: 3-17            [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─Sequential: 3-18             [100, 64, 40, 40]         [100, 128, 20, 20]        --
# │    │    └─ReLU: 3-19                   [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    └─BasicBlock: 2-4                   [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─Conv2d: 3-20                 [100, 128, 20, 20]        [100, 128, 20, 20]        [3, 3]
# │    │    └─BatchNorm2d: 3-21            [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─ReLU: 3-22                   [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─Conv2d: 3-23                 [100, 128, 20, 20]        [100, 128, 20, 20]        [3, 3]
# │    │    └─BatchNorm2d: 3-24            [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─ReLU: 3-25                   [100, 128, 20, 20]        [100, 128, 20, 20]        --
# ├─Sequential: 1-7                        [100, 128, 20, 20]        [100, 256, 10, 10]        --
# │    └─BasicBlock: 2-5                   [100, 128, 20, 20]        [100, 256, 10, 10]        --
# │    │    └─Conv2d: 3-26                 [100, 128, 20, 20]        [100, 256, 10, 10]        [3, 3]
# │    │    └─BatchNorm2d: 3-27            [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─ReLU: 3-28                   [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─Conv2d: 3-29                 [100, 256, 10, 10]        [100, 256, 10, 10]        [3, 3]
# │    │    └─BatchNorm2d: 3-30            [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─Sequential: 3-31             [100, 128, 20, 20]        [100, 256, 10, 10]        --
# │    │    └─ReLU: 3-32                   [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    └─BasicBlock: 2-6                   [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─Conv2d: 3-33                 [100, 256, 10, 10]        [100, 256, 10, 10]        [3, 3]
# │    │    └─BatchNorm2d: 3-34            [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─ReLU: 3-35                   [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─Conv2d: 3-36                 [100, 256, 10, 10]        [100, 256, 10, 10]        [3, 3]
# │    │    └─BatchNorm2d: 3-37            [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─ReLU: 3-38                   [100, 256, 10, 10]        [100, 256, 10, 10]        --
# ├─Sequential: 1-8                        [100, 256, 10, 10]        [100, 512, 5, 5]          --
# │    └─BasicBlock: 2-7                   [100, 256, 10, 10]        [100, 512, 5, 5]          --
# │    │    └─Conv2d: 3-39                 [100, 256, 10, 10]        [100, 512, 5, 5]          [3, 3]
# │    │    └─BatchNorm2d: 3-40            [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    │    └─ReLU: 3-41                   [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    │    └─Conv2d: 3-42                 [100, 512, 5, 5]          [100, 512, 5, 5]          [3, 3]
# │    │    └─BatchNorm2d: 3-43            [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    │    └─Sequential: 3-44             [100, 256, 10, 10]        [100, 512, 5, 5]          --
# │    │    └─ReLU: 3-45                   [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    └─BasicBlock: 2-8                   [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    │    └─Conv2d: 3-46                 [100, 512, 5, 5]          [100, 512, 5, 5]          [3, 3]
# │    │    └─BatchNorm2d: 3-47            [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    │    └─ReLU: 3-48                   [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    │    └─Conv2d: 3-49                 [100, 512, 5, 5]          [100, 512, 5, 5]          [3, 3]
# │    │    └─BatchNorm2d: 3-50            [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    │    └─ReLU: 3-51                   [100, 512, 5, 5]          [100, 512, 5, 5]          --
# ├─AdaptiveAvgPool2d: 1-9                 [100, 512, 5, 5]          [100, 512, 1, 1]          --
# ├─Linear: 1-10                           [100, 512]                [100, 1000]               --
# ===================================================================================================================
# Total params: 11,689,512
# Trainable params: 11,689,512
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 92.58
# ===================================================================================================================
# Input size (MB): 30.72
# Forward/backward pass size (MB): 2028.32
# Params size (MB): 46.76
# Estimated Total Size (MB): 2105.80
# ===================================================================================================================

# %% [markdown]
# ## G_resnet18

# %%
#summarise('g_resnet18')

# %% [markdown]
# ## Resnet50

# %%
summarise('resnet50')
# Out:
# ===================================================================================================================
# Layer (type:depth-idx)                   Input Shape               Output Shape              Kernel Shape
# ===================================================================================================================
# ResNet                                   [100, 3, 160, 160]        [100, 1000]               --
# ├─Conv2d: 1-1                            [100, 3, 160, 160]        [100, 64, 80, 80]         [7, 7]
# ├─BatchNorm2d: 1-2                       [100, 64, 80, 80]         [100, 64, 80, 80]         --
# ├─ReLU: 1-3                              [100, 64, 80, 80]         [100, 64, 80, 80]         --
# ├─MaxPool2d: 1-4                         [100, 64, 80, 80]         [100, 64, 40, 40]         3
# ├─Sequential: 1-5                        [100, 64, 40, 40]         [100, 256, 40, 40]        --
# │    └─Bottleneck: 2-1                   [100, 64, 40, 40]         [100, 256, 40, 40]        --
# │    │    └─Conv2d: 3-1                  [100, 64, 40, 40]         [100, 64, 40, 40]         [1, 1]
# │    │    └─BatchNorm2d: 3-2             [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─ReLU: 3-3                    [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─Conv2d: 3-4                  [100, 64, 40, 40]         [100, 64, 40, 40]         [3, 3]
# │    │    └─BatchNorm2d: 3-5             [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─ReLU: 3-6                    [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─Conv2d: 3-7                  [100, 64, 40, 40]         [100, 256, 40, 40]        [1, 1]
# │    │    └─BatchNorm2d: 3-8             [100, 256, 40, 40]        [100, 256, 40, 40]        --
# │    │    └─Sequential: 3-9              [100, 64, 40, 40]         [100, 256, 40, 40]        --
# │    │    └─ReLU: 3-10                   [100, 256, 40, 40]        [100, 256, 40, 40]        --
# │    └─Bottleneck: 2-2                   [100, 256, 40, 40]        [100, 256, 40, 40]        --
# │    │    └─Conv2d: 3-11                 [100, 256, 40, 40]        [100, 64, 40, 40]         [1, 1]
# │    │    └─BatchNorm2d: 3-12            [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─ReLU: 3-13                   [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─Conv2d: 3-14                 [100, 64, 40, 40]         [100, 64, 40, 40]         [3, 3]
# │    │    └─BatchNorm2d: 3-15            [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─ReLU: 3-16                   [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─Conv2d: 3-17                 [100, 64, 40, 40]         [100, 256, 40, 40]        [1, 1]
# │    │    └─BatchNorm2d: 3-18            [100, 256, 40, 40]        [100, 256, 40, 40]        --
# │    │    └─ReLU: 3-19                   [100, 256, 40, 40]        [100, 256, 40, 40]        --
# │    └─Bottleneck: 2-3                   [100, 256, 40, 40]        [100, 256, 40, 40]        --
# │    │    └─Conv2d: 3-20                 [100, 256, 40, 40]        [100, 64, 40, 40]         [1, 1]
# │    │    └─BatchNorm2d: 3-21            [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─ReLU: 3-22                   [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─Conv2d: 3-23                 [100, 64, 40, 40]         [100, 64, 40, 40]         [3, 3]
# │    │    └─BatchNorm2d: 3-24            [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─ReLU: 3-25                   [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─Conv2d: 3-26                 [100, 64, 40, 40]         [100, 256, 40, 40]        [1, 1]
# │    │    └─BatchNorm2d: 3-27            [100, 256, 40, 40]        [100, 256, 40, 40]        --
# │    │    └─ReLU: 3-28                   [100, 256, 40, 40]        [100, 256, 40, 40]        --
# ├─Sequential: 1-6                        [100, 256, 40, 40]        [100, 512, 20, 20]        --
# │    └─Bottleneck: 2-4                   [100, 256, 40, 40]        [100, 512, 20, 20]        --
# │    │    └─Conv2d: 3-29                 [100, 256, 40, 40]        [100, 128, 40, 40]        [1, 1]
# │    │    └─BatchNorm2d: 3-30            [100, 128, 40, 40]        [100, 128, 40, 40]        --
# │    │    └─ReLU: 3-31                   [100, 128, 40, 40]        [100, 128, 40, 40]        --
# │    │    └─Conv2d: 3-32                 [100, 128, 40, 40]        [100, 128, 20, 20]        [3, 3]
# │    │    └─BatchNorm2d: 3-33            [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─ReLU: 3-34                   [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─Conv2d: 3-35                 [100, 128, 20, 20]        [100, 512, 20, 20]        [1, 1]
# │    │    └─BatchNorm2d: 3-36            [100, 512, 20, 20]        [100, 512, 20, 20]        --
# │    │    └─Sequential: 3-37             [100, 256, 40, 40]        [100, 512, 20, 20]        --
# │    │    └─ReLU: 3-38                   [100, 512, 20, 20]        [100, 512, 20, 20]        --
# │    └─Bottleneck: 2-5                   [100, 512, 20, 20]        [100, 512, 20, 20]        --
# │    │    └─Conv2d: 3-39                 [100, 512, 20, 20]        [100, 128, 20, 20]        [1, 1]
# │    │    └─BatchNorm2d: 3-40            [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─ReLU: 3-41                   [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─Conv2d: 3-42                 [100, 128, 20, 20]        [100, 128, 20, 20]        [3, 3]
# │    │    └─BatchNorm2d: 3-43            [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─ReLU: 3-44                   [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─Conv2d: 3-45                 [100, 128, 20, 20]        [100, 512, 20, 20]        [1, 1]
# │    │    └─BatchNorm2d: 3-46            [100, 512, 20, 20]        [100, 512, 20, 20]        --
# │    │    └─ReLU: 3-47                   [100, 512, 20, 20]        [100, 512, 20, 20]        --
# │    └─Bottleneck: 2-6                   [100, 512, 20, 20]        [100, 512, 20, 20]        --
# │    │    └─Conv2d: 3-48                 [100, 512, 20, 20]        [100, 128, 20, 20]        [1, 1]
# │    │    └─BatchNorm2d: 3-49            [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─ReLU: 3-50                   [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─Conv2d: 3-51                 [100, 128, 20, 20]        [100, 128, 20, 20]        [3, 3]
# │    │    └─BatchNorm2d: 3-52            [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─ReLU: 3-53                   [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─Conv2d: 3-54                 [100, 128, 20, 20]        [100, 512, 20, 20]        [1, 1]
# │    │    └─BatchNorm2d: 3-55            [100, 512, 20, 20]        [100, 512, 20, 20]        --
# │    │    └─ReLU: 3-56                   [100, 512, 20, 20]        [100, 512, 20, 20]        --
# │    └─Bottleneck: 2-7                   [100, 512, 20, 20]        [100, 512, 20, 20]        --
# │    │    └─Conv2d: 3-57                 [100, 512, 20, 20]        [100, 128, 20, 20]        [1, 1]
# │    │    └─BatchNorm2d: 3-58            [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─ReLU: 3-59                   [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─Conv2d: 3-60                 [100, 128, 20, 20]        [100, 128, 20, 20]        [3, 3]
# │    │    └─BatchNorm2d: 3-61            [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─ReLU: 3-62                   [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─Conv2d: 3-63                 [100, 128, 20, 20]        [100, 512, 20, 20]        [1, 1]
# │    │    └─BatchNorm2d: 3-64            [100, 512, 20, 20]        [100, 512, 20, 20]        --
# │    │    └─ReLU: 3-65                   [100, 512, 20, 20]        [100, 512, 20, 20]        --
# ├─Sequential: 1-7                        [100, 512, 20, 20]        [100, 1024, 10, 10]       --
# │    └─Bottleneck: 2-8                   [100, 512, 20, 20]        [100, 1024, 10, 10]       --
# │    │    └─Conv2d: 3-66                 [100, 512, 20, 20]        [100, 256, 20, 20]        [1, 1]
# │    │    └─BatchNorm2d: 3-67            [100, 256, 20, 20]        [100, 256, 20, 20]        --
# │    │    └─ReLU: 3-68                   [100, 256, 20, 20]        [100, 256, 20, 20]        --
# │    │    └─Conv2d: 3-69                 [100, 256, 20, 20]        [100, 256, 10, 10]        [3, 3]
# │    │    └─BatchNorm2d: 3-70            [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─ReLU: 3-71                   [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─Conv2d: 3-72                 [100, 256, 10, 10]        [100, 1024, 10, 10]       [1, 1]
# │    │    └─BatchNorm2d: 3-73            [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    │    └─Sequential: 3-74             [100, 512, 20, 20]        [100, 1024, 10, 10]       --
# │    │    └─ReLU: 3-75                   [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    └─Bottleneck: 2-9                   [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    │    └─Conv2d: 3-76                 [100, 1024, 10, 10]       [100, 256, 10, 10]        [1, 1]
# │    │    └─BatchNorm2d: 3-77            [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─ReLU: 3-78                   [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─Conv2d: 3-79                 [100, 256, 10, 10]        [100, 256, 10, 10]        [3, 3]
# │    │    └─BatchNorm2d: 3-80            [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─ReLU: 3-81                   [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─Conv2d: 3-82                 [100, 256, 10, 10]        [100, 1024, 10, 10]       [1, 1]
# │    │    └─BatchNorm2d: 3-83            [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    │    └─ReLU: 3-84                   [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    └─Bottleneck: 2-10                  [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    │    └─Conv2d: 3-85                 [100, 1024, 10, 10]       [100, 256, 10, 10]        [1, 1]
# │    │    └─BatchNorm2d: 3-86            [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─ReLU: 3-87                   [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─Conv2d: 3-88                 [100, 256, 10, 10]        [100, 256, 10, 10]        [3, 3]
# │    │    └─BatchNorm2d: 3-89            [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─ReLU: 3-90                   [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─Conv2d: 3-91                 [100, 256, 10, 10]        [100, 1024, 10, 10]       [1, 1]
# │    │    └─BatchNorm2d: 3-92            [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    │    └─ReLU: 3-93                   [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    └─Bottleneck: 2-11                  [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    │    └─Conv2d: 3-94                 [100, 1024, 10, 10]       [100, 256, 10, 10]        [1, 1]
# │    │    └─BatchNorm2d: 3-95            [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─ReLU: 3-96                   [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─Conv2d: 3-97                 [100, 256, 10, 10]        [100, 256, 10, 10]        [3, 3]
# │    │    └─BatchNorm2d: 3-98            [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─ReLU: 3-99                   [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─Conv2d: 3-100                [100, 256, 10, 10]        [100, 1024, 10, 10]       [1, 1]
# │    │    └─BatchNorm2d: 3-101           [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    │    └─ReLU: 3-102                  [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    └─Bottleneck: 2-12                  [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    │    └─Conv2d: 3-103                [100, 1024, 10, 10]       [100, 256, 10, 10]        [1, 1]
# │    │    └─BatchNorm2d: 3-104           [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─ReLU: 3-105                  [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─Conv2d: 3-106                [100, 256, 10, 10]        [100, 256, 10, 10]        [3, 3]
# │    │    └─BatchNorm2d: 3-107           [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─ReLU: 3-108                  [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─Conv2d: 3-109                [100, 256, 10, 10]        [100, 1024, 10, 10]       [1, 1]
# │    │    └─BatchNorm2d: 3-110           [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    │    └─ReLU: 3-111                  [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    └─Bottleneck: 2-13                  [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    │    └─Conv2d: 3-112                [100, 1024, 10, 10]       [100, 256, 10, 10]        [1, 1]
# │    │    └─BatchNorm2d: 3-113           [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─ReLU: 3-114                  [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─Conv2d: 3-115                [100, 256, 10, 10]        [100, 256, 10, 10]        [3, 3]
# │    │    └─BatchNorm2d: 3-116           [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─ReLU: 3-117                  [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─Conv2d: 3-118                [100, 256, 10, 10]        [100, 1024, 10, 10]       [1, 1]
# │    │    └─BatchNorm2d: 3-119           [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    │    └─ReLU: 3-120                  [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# ├─Sequential: 1-8                        [100, 1024, 10, 10]       [100, 2048, 5, 5]         --
# │    └─Bottleneck: 2-14                  [100, 1024, 10, 10]       [100, 2048, 5, 5]         --
# │    │    └─Conv2d: 3-121                [100, 1024, 10, 10]       [100, 512, 10, 10]        [1, 1]
# │    │    └─BatchNorm2d: 3-122           [100, 512, 10, 10]        [100, 512, 10, 10]        --
# │    │    └─ReLU: 3-123                  [100, 512, 10, 10]        [100, 512, 10, 10]        --
# │    │    └─Conv2d: 3-124                [100, 512, 10, 10]        [100, 512, 5, 5]          [3, 3]
# │    │    └─BatchNorm2d: 3-125           [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    │    └─ReLU: 3-126                  [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    │    └─Conv2d: 3-127                [100, 512, 5, 5]          [100, 2048, 5, 5]         [1, 1]
# │    │    └─BatchNorm2d: 3-128           [100, 2048, 5, 5]         [100, 2048, 5, 5]         --
# │    │    └─Sequential: 3-129            [100, 1024, 10, 10]       [100, 2048, 5, 5]         --
# │    │    └─ReLU: 3-130                  [100, 2048, 5, 5]         [100, 2048, 5, 5]         --
# │    └─Bottleneck: 2-15                  [100, 2048, 5, 5]         [100, 2048, 5, 5]         --
# │    │    └─Conv2d: 3-131                [100, 2048, 5, 5]         [100, 512, 5, 5]          [1, 1]
# │    │    └─BatchNorm2d: 3-132           [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    │    └─ReLU: 3-133                  [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    │    └─Conv2d: 3-134                [100, 512, 5, 5]          [100, 512, 5, 5]          [3, 3]
# │    │    └─BatchNorm2d: 3-135           [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    │    └─ReLU: 3-136                  [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    │    └─Conv2d: 3-137                [100, 512, 5, 5]          [100, 2048, 5, 5]         [1, 1]
# │    │    └─BatchNorm2d: 3-138           [100, 2048, 5, 5]         [100, 2048, 5, 5]         --
# │    │    └─ReLU: 3-139                  [100, 2048, 5, 5]         [100, 2048, 5, 5]         --
# │    └─Bottleneck: 2-16                  [100, 2048, 5, 5]         [100, 2048, 5, 5]         --
# │    │    └─Conv2d: 3-140                [100, 2048, 5, 5]         [100, 512, 5, 5]          [1, 1]
# │    │    └─BatchNorm2d: 3-141           [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    │    └─ReLU: 3-142                  [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    │    └─Conv2d: 3-143                [100, 512, 5, 5]          [100, 512, 5, 5]          [3, 3]
# │    │    └─BatchNorm2d: 3-144           [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    │    └─ReLU: 3-145                  [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    │    └─Conv2d: 3-146                [100, 512, 5, 5]          [100, 2048, 5, 5]         [1, 1]
# │    │    └─BatchNorm2d: 3-147           [100, 2048, 5, 5]         [100, 2048, 5, 5]         --
# │    │    └─ReLU: 3-148                  [100, 2048, 5, 5]         [100, 2048, 5, 5]         --
# ├─AdaptiveAvgPool2d: 1-9                 [100, 2048, 5, 5]         [100, 2048, 1, 1]         --
# ├─Linear: 1-10                           [100, 2048]               [100, 1000]               --
# ===================================================================================================================
# Total params: 25,557,032
# Trainable params: 25,557,032
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 208.74
# ===================================================================================================================
# Input size (MB): 30.72
# Forward/backward pass size (MB): 9073.44
# Params size (MB): 102.23
# Estimated Total Size (MB): 9206.39
# ===================================================================================================================

# %% [markdown]
# ## JiaResnet50

# %%
summarise('jiaresnet50')
# Out:
# ===================================================================================================================
# Layer (type:depth-idx)                   Input Shape               Output Shape              Kernel Shape
# ===================================================================================================================
# JiaResnet                                [100, 3, 160, 160]        [100, 2]                  --
# ├─Conv2d: 1-1                            [100, 3, 160, 160]        [100, 64, 80, 80]         [7, 7]
# ├─BatchNorm2d: 1-2                       [100, 64, 80, 80]         [100, 64, 80, 80]         --
# ├─ReLU: 1-3                              [100, 64, 80, 80]         [100, 64, 80, 80]         --
# ├─MaxPool2d: 1-4                         [100, 64, 80, 80]         [100, 64, 40, 40]         3
# ├─Sequential: 1-5                        [100, 64, 40, 40]         [100, 256, 40, 40]        --
# │    └─Bottleneck: 2-1                   [100, 64, 40, 40]         [100, 256, 40, 40]        --
# │    │    └─Conv2d: 3-1                  [100, 64, 40, 40]         [100, 64, 40, 40]         [1, 1]
# │    │    └─BatchNorm2d: 3-2             [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─ReLU: 3-3                    [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─Conv2d: 3-4                  [100, 64, 40, 40]         [100, 64, 40, 40]         [3, 3]
# │    │    └─BatchNorm2d: 3-5             [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─ReLU: 3-6                    [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─Conv2d: 3-7                  [100, 64, 40, 40]         [100, 256, 40, 40]        [1, 1]
# │    │    └─BatchNorm2d: 3-8             [100, 256, 40, 40]        [100, 256, 40, 40]        --
# │    │    └─Sequential: 3-9              [100, 64, 40, 40]         [100, 256, 40, 40]        --
# │    │    └─ReLU: 3-10                   [100, 256, 40, 40]        [100, 256, 40, 40]        --
# │    └─Bottleneck: 2-2                   [100, 256, 40, 40]        [100, 256, 40, 40]        --
# │    │    └─Conv2d: 3-11                 [100, 256, 40, 40]        [100, 64, 40, 40]         [1, 1]
# │    │    └─BatchNorm2d: 3-12            [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─ReLU: 3-13                   [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─Conv2d: 3-14                 [100, 64, 40, 40]         [100, 64, 40, 40]         [3, 3]
# │    │    └─BatchNorm2d: 3-15            [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─ReLU: 3-16                   [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─Conv2d: 3-17                 [100, 64, 40, 40]         [100, 256, 40, 40]        [1, 1]
# │    │    └─BatchNorm2d: 3-18            [100, 256, 40, 40]        [100, 256, 40, 40]        --
# │    │    └─ReLU: 3-19                   [100, 256, 40, 40]        [100, 256, 40, 40]        --
# │    └─Bottleneck: 2-3                   [100, 256, 40, 40]        [100, 256, 40, 40]        --
# │    │    └─Conv2d: 3-20                 [100, 256, 40, 40]        [100, 64, 40, 40]         [1, 1]
# │    │    └─BatchNorm2d: 3-21            [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─ReLU: 3-22                   [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─Conv2d: 3-23                 [100, 64, 40, 40]         [100, 64, 40, 40]         [3, 3]
# │    │    └─BatchNorm2d: 3-24            [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─ReLU: 3-25                   [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─Conv2d: 3-26                 [100, 64, 40, 40]         [100, 256, 40, 40]        [1, 1]
# │    │    └─BatchNorm2d: 3-27            [100, 256, 40, 40]        [100, 256, 40, 40]        --
# │    │    └─ReLU: 3-28                   [100, 256, 40, 40]        [100, 256, 40, 40]        --
# ├─Sequential: 1-6                        [100, 256, 40, 40]        [100, 512, 20, 20]        --
# │    └─Bottleneck: 2-4                   [100, 256, 40, 40]        [100, 512, 20, 20]        --
# │    │    └─Conv2d: 3-29                 [100, 256, 40, 40]        [100, 128, 40, 40]        [1, 1]
# │    │    └─BatchNorm2d: 3-30            [100, 128, 40, 40]        [100, 128, 40, 40]        --
# │    │    └─ReLU: 3-31                   [100, 128, 40, 40]        [100, 128, 40, 40]        --
# │    │    └─Conv2d: 3-32                 [100, 128, 40, 40]        [100, 128, 20, 20]        [3, 3]
# │    │    └─BatchNorm2d: 3-33            [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─ReLU: 3-34                   [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─Conv2d: 3-35                 [100, 128, 20, 20]        [100, 512, 20, 20]        [1, 1]
# │    │    └─BatchNorm2d: 3-36            [100, 512, 20, 20]        [100, 512, 20, 20]        --
# │    │    └─Sequential: 3-37             [100, 256, 40, 40]        [100, 512, 20, 20]        --
# │    │    └─ReLU: 3-38                   [100, 512, 20, 20]        [100, 512, 20, 20]        --
# │    └─Bottleneck: 2-5                   [100, 512, 20, 20]        [100, 512, 20, 20]        --
# │    │    └─Conv2d: 3-39                 [100, 512, 20, 20]        [100, 128, 20, 20]        [1, 1]
# │    │    └─BatchNorm2d: 3-40            [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─ReLU: 3-41                   [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─Conv2d: 3-42                 [100, 128, 20, 20]        [100, 128, 20, 20]        [3, 3]
# │    │    └─BatchNorm2d: 3-43            [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─ReLU: 3-44                   [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─Conv2d: 3-45                 [100, 128, 20, 20]        [100, 512, 20, 20]        [1, 1]
# │    │    └─BatchNorm2d: 3-46            [100, 512, 20, 20]        [100, 512, 20, 20]        --
# │    │    └─ReLU: 3-47                   [100, 512, 20, 20]        [100, 512, 20, 20]        --
# │    └─Bottleneck: 2-6                   [100, 512, 20, 20]        [100, 512, 20, 20]        --
# │    │    └─Conv2d: 3-48                 [100, 512, 20, 20]        [100, 128, 20, 20]        [1, 1]
# │    │    └─BatchNorm2d: 3-49            [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─ReLU: 3-50                   [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─Conv2d: 3-51                 [100, 128, 20, 20]        [100, 128, 20, 20]        [3, 3]
# │    │    └─BatchNorm2d: 3-52            [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─ReLU: 3-53                   [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─Conv2d: 3-54                 [100, 128, 20, 20]        [100, 512, 20, 20]        [1, 1]
# │    │    └─BatchNorm2d: 3-55            [100, 512, 20, 20]        [100, 512, 20, 20]        --
# │    │    └─ReLU: 3-56                   [100, 512, 20, 20]        [100, 512, 20, 20]        --
# │    └─Bottleneck: 2-7                   [100, 512, 20, 20]        [100, 512, 20, 20]        --
# │    │    └─Conv2d: 3-57                 [100, 512, 20, 20]        [100, 128, 20, 20]        [1, 1]
# │    │    └─BatchNorm2d: 3-58            [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─ReLU: 3-59                   [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─Conv2d: 3-60                 [100, 128, 20, 20]        [100, 128, 20, 20]        [3, 3]
# │    │    └─BatchNorm2d: 3-61            [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─ReLU: 3-62                   [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─Conv2d: 3-63                 [100, 128, 20, 20]        [100, 512, 20, 20]        [1, 1]
# │    │    └─BatchNorm2d: 3-64            [100, 512, 20, 20]        [100, 512, 20, 20]        --
# │    │    └─ReLU: 3-65                   [100, 512, 20, 20]        [100, 512, 20, 20]        --
# ├─Sequential: 1-7                        [100, 512, 20, 20]        [100, 1024, 10, 10]       --
# │    └─Bottleneck: 2-8                   [100, 512, 20, 20]        [100, 1024, 10, 10]       --
# │    │    └─Conv2d: 3-66                 [100, 512, 20, 20]        [100, 256, 20, 20]        [1, 1]
# │    │    └─BatchNorm2d: 3-67            [100, 256, 20, 20]        [100, 256, 20, 20]        --
# │    │    └─ReLU: 3-68                   [100, 256, 20, 20]        [100, 256, 20, 20]        --
# │    │    └─Conv2d: 3-69                 [100, 256, 20, 20]        [100, 256, 10, 10]        [3, 3]
# │    │    └─BatchNorm2d: 3-70            [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─ReLU: 3-71                   [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─Conv2d: 3-72                 [100, 256, 10, 10]        [100, 1024, 10, 10]       [1, 1]
# │    │    └─BatchNorm2d: 3-73            [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    │    └─Sequential: 3-74             [100, 512, 20, 20]        [100, 1024, 10, 10]       --
# │    │    └─ReLU: 3-75                   [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    └─Bottleneck: 2-9                   [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    │    └─Conv2d: 3-76                 [100, 1024, 10, 10]       [100, 256, 10, 10]        [1, 1]
# │    │    └─BatchNorm2d: 3-77            [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─ReLU: 3-78                   [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─Conv2d: 3-79                 [100, 256, 10, 10]        [100, 256, 10, 10]        [3, 3]
# │    │    └─BatchNorm2d: 3-80            [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─ReLU: 3-81                   [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─Conv2d: 3-82                 [100, 256, 10, 10]        [100, 1024, 10, 10]       [1, 1]
# │    │    └─BatchNorm2d: 3-83            [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    │    └─ReLU: 3-84                   [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    └─Bottleneck: 2-10                  [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    │    └─Conv2d: 3-85                 [100, 1024, 10, 10]       [100, 256, 10, 10]        [1, 1]
# │    │    └─BatchNorm2d: 3-86            [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─ReLU: 3-87                   [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─Conv2d: 3-88                 [100, 256, 10, 10]        [100, 256, 10, 10]        [3, 3]
# │    │    └─BatchNorm2d: 3-89            [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─ReLU: 3-90                   [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─Conv2d: 3-91                 [100, 256, 10, 10]        [100, 1024, 10, 10]       [1, 1]
# │    │    └─BatchNorm2d: 3-92            [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    │    └─ReLU: 3-93                   [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    └─Bottleneck: 2-11                  [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    │    └─Conv2d: 3-94                 [100, 1024, 10, 10]       [100, 256, 10, 10]        [1, 1]
# │    │    └─BatchNorm2d: 3-95            [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─ReLU: 3-96                   [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─Conv2d: 3-97                 [100, 256, 10, 10]        [100, 256, 10, 10]        [3, 3]
# │    │    └─BatchNorm2d: 3-98            [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─ReLU: 3-99                   [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─Conv2d: 3-100                [100, 256, 10, 10]        [100, 1024, 10, 10]       [1, 1]
# │    │    └─BatchNorm2d: 3-101           [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    │    └─ReLU: 3-102                  [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    └─Bottleneck: 2-12                  [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    │    └─Conv2d: 3-103                [100, 1024, 10, 10]       [100, 256, 10, 10]        [1, 1]
# │    │    └─BatchNorm2d: 3-104           [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─ReLU: 3-105                  [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─Conv2d: 3-106                [100, 256, 10, 10]        [100, 256, 10, 10]        [3, 3]
# │    │    └─BatchNorm2d: 3-107           [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─ReLU: 3-108                  [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─Conv2d: 3-109                [100, 256, 10, 10]        [100, 1024, 10, 10]       [1, 1]
# │    │    └─BatchNorm2d: 3-110           [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    │    └─ReLU: 3-111                  [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    └─Bottleneck: 2-13                  [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    │    └─Conv2d: 3-112                [100, 1024, 10, 10]       [100, 256, 10, 10]        [1, 1]
# │    │    └─BatchNorm2d: 3-113           [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─ReLU: 3-114                  [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─Conv2d: 3-115                [100, 256, 10, 10]        [100, 256, 10, 10]        [3, 3]
# │    │    └─BatchNorm2d: 3-116           [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─ReLU: 3-117                  [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─Conv2d: 3-118                [100, 256, 10, 10]        [100, 1024, 10, 10]       [1, 1]
# │    │    └─BatchNorm2d: 3-119           [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    │    └─ReLU: 3-120                  [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# ├─Sequential: 1-8                        [100, 1024, 10, 10]       [100, 2048, 5, 5]         --
# │    └─Bottleneck: 2-14                  [100, 1024, 10, 10]       [100, 2048, 5, 5]         --
# │    │    └─Conv2d: 3-121                [100, 1024, 10, 10]       [100, 512, 10, 10]        [1, 1]
# │    │    └─BatchNorm2d: 3-122           [100, 512, 10, 10]        [100, 512, 10, 10]        --
# │    │    └─ReLU: 3-123                  [100, 512, 10, 10]        [100, 512, 10, 10]        --
# │    │    └─Conv2d: 3-124                [100, 512, 10, 10]        [100, 512, 5, 5]          [3, 3]
# │    │    └─BatchNorm2d: 3-125           [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    │    └─ReLU: 3-126                  [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    │    └─Conv2d: 3-127                [100, 512, 5, 5]          [100, 2048, 5, 5]         [1, 1]
# │    │    └─BatchNorm2d: 3-128           [100, 2048, 5, 5]         [100, 2048, 5, 5]         --
# │    │    └─Sequential: 3-129            [100, 1024, 10, 10]       [100, 2048, 5, 5]         --
# │    │    └─ReLU: 3-130                  [100, 2048, 5, 5]         [100, 2048, 5, 5]         --
# │    └─Bottleneck: 2-15                  [100, 2048, 5, 5]         [100, 2048, 5, 5]         --
# │    │    └─Conv2d: 3-131                [100, 2048, 5, 5]         [100, 512, 5, 5]          [1, 1]
# │    │    └─BatchNorm2d: 3-132           [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    │    └─ReLU: 3-133                  [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    │    └─Conv2d: 3-134                [100, 512, 5, 5]          [100, 512, 5, 5]          [3, 3]
# │    │    └─BatchNorm2d: 3-135           [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    │    └─ReLU: 3-136                  [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    │    └─Conv2d: 3-137                [100, 512, 5, 5]          [100, 2048, 5, 5]         [1, 1]
# │    │    └─BatchNorm2d: 3-138           [100, 2048, 5, 5]         [100, 2048, 5, 5]         --
# │    │    └─ReLU: 3-139                  [100, 2048, 5, 5]         [100, 2048, 5, 5]         --
# │    └─Bottleneck: 2-16                  [100, 2048, 5, 5]         [100, 2048, 5, 5]         --
# │    │    └─Conv2d: 3-140                [100, 2048, 5, 5]         [100, 512, 5, 5]          [1, 1]
# │    │    └─BatchNorm2d: 3-141           [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    │    └─ReLU: 3-142                  [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    │    └─Conv2d: 3-143                [100, 512, 5, 5]          [100, 512, 5, 5]          [3, 3]
# │    │    └─BatchNorm2d: 3-144           [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    │    └─ReLU: 3-145                  [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    │    └─Conv2d: 3-146                [100, 512, 5, 5]          [100, 2048, 5, 5]         [1, 1]
# │    │    └─BatchNorm2d: 3-147           [100, 2048, 5, 5]         [100, 2048, 5, 5]         --
# │    │    └─ReLU: 3-148                  [100, 2048, 5, 5]         [100, 2048, 5, 5]         --
# ├─AdaptiveAvgPool2d: 1-9                 [100, 2048, 5, 5]         [100, 2048, 1, 1]         --
# ├─Sequential: 1-10                       [100, 2048]               [100, 2]                  --
# │    └─Linear: 2-17                      [100, 2048]               [100, 512]                --
# │    └─Tanh: 2-18                        [100, 512]                [100, 512]                --
# │    └─Linear: 2-19                      [100, 512]                [100, 512]                --
# │    └─Tanh: 2-20                        [100, 512]                [100, 512]                --
# │    └─Linear: 2-21                      [100, 512]                [100, 64]                 --
# │    └─Tanh: 2-22                        [100, 64]                 [100, 64]                 --
# │    └─Linear: 2-23                      [100, 64]                 [100, 64]                 --
# │    └─Tanh: 2-24                        [100, 64]                 [100, 64]                 --
# │    └─Linear: 2-25                      [100, 64]                 [100, 2]                  --
# JiaResnet                                [100, 3, 160, 160]        [100, 2]                  --
# ├─Conv2d: 1-11                           [100, 3, 160, 160]        [100, 64, 80, 80]         [7, 7]
# ├─BatchNorm2d: 1-12                      [100, 64, 80, 80]         [100, 64, 80, 80]         --
# ├─ReLU: 1-13                             [100, 64, 80, 80]         [100, 64, 80, 80]         --
# ├─MaxPool2d: 1-14                        [100, 64, 80, 80]         [100, 64, 40, 40]         3
# ├─Sequential: 1-15                       [100, 64, 40, 40]         [100, 256, 40, 40]        --
# │    └─Bottleneck: 2-26                  [100, 64, 40, 40]         [100, 256, 40, 40]        --
# │    │    └─Conv2d: 3-149                [100, 64, 40, 40]         [100, 64, 40, 40]         [1, 1]
# │    │    └─BatchNorm2d: 3-150           [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─ReLU: 3-151                  [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─Conv2d: 3-152                [100, 64, 40, 40]         [100, 64, 40, 40]         [3, 3]
# │    │    └─BatchNorm2d: 3-153           [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─ReLU: 3-154                  [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─Conv2d: 3-155                [100, 64, 40, 40]         [100, 256, 40, 40]        [1, 1]
# │    │    └─BatchNorm2d: 3-156           [100, 256, 40, 40]        [100, 256, 40, 40]        --
# │    │    └─Sequential: 3-157            [100, 64, 40, 40]         [100, 256, 40, 40]        --
# │    │    └─ReLU: 3-158                  [100, 256, 40, 40]        [100, 256, 40, 40]        --
# │    └─Bottleneck: 2-27                  [100, 256, 40, 40]        [100, 256, 40, 40]        --
# │    │    └─Conv2d: 3-159                [100, 256, 40, 40]        [100, 64, 40, 40]         [1, 1]
# │    │    └─BatchNorm2d: 3-160           [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─ReLU: 3-161                  [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─Conv2d: 3-162                [100, 64, 40, 40]         [100, 64, 40, 40]         [3, 3]
# │    │    └─BatchNorm2d: 3-163           [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─ReLU: 3-164                  [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─Conv2d: 3-165                [100, 64, 40, 40]         [100, 256, 40, 40]        [1, 1]
# │    │    └─BatchNorm2d: 3-166           [100, 256, 40, 40]        [100, 256, 40, 40]        --
# │    │    └─ReLU: 3-167                  [100, 256, 40, 40]        [100, 256, 40, 40]        --
# │    └─Bottleneck: 2-28                  [100, 256, 40, 40]        [100, 256, 40, 40]        --
# │    │    └─Conv2d: 3-168                [100, 256, 40, 40]        [100, 64, 40, 40]         [1, 1]
# │    │    └─BatchNorm2d: 3-169           [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─ReLU: 3-170                  [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─Conv2d: 3-171                [100, 64, 40, 40]         [100, 64, 40, 40]         [3, 3]
# │    │    └─BatchNorm2d: 3-172           [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─ReLU: 3-173                  [100, 64, 40, 40]         [100, 64, 40, 40]         --
# │    │    └─Conv2d: 3-174                [100, 64, 40, 40]         [100, 256, 40, 40]        [1, 1]
# │    │    └─BatchNorm2d: 3-175           [100, 256, 40, 40]        [100, 256, 40, 40]        --
# │    │    └─ReLU: 3-176                  [100, 256, 40, 40]        [100, 256, 40, 40]        --
# ├─Sequential: 1-16                       [100, 256, 40, 40]        [100, 512, 20, 20]        --
# │    └─Bottleneck: 2-29                  [100, 256, 40, 40]        [100, 512, 20, 20]        --
# │    │    └─Conv2d: 3-177                [100, 256, 40, 40]        [100, 128, 40, 40]        [1, 1]
# │    │    └─BatchNorm2d: 3-178           [100, 128, 40, 40]        [100, 128, 40, 40]        --
# │    │    └─ReLU: 3-179                  [100, 128, 40, 40]        [100, 128, 40, 40]        --
# │    │    └─Conv2d: 3-180                [100, 128, 40, 40]        [100, 128, 20, 20]        [3, 3]
# │    │    └─BatchNorm2d: 3-181           [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─ReLU: 3-182                  [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─Conv2d: 3-183                [100, 128, 20, 20]        [100, 512, 20, 20]        [1, 1]
# │    │    └─BatchNorm2d: 3-184           [100, 512, 20, 20]        [100, 512, 20, 20]        --
# │    │    └─Sequential: 3-185            [100, 256, 40, 40]        [100, 512, 20, 20]        --
# │    │    └─ReLU: 3-186                  [100, 512, 20, 20]        [100, 512, 20, 20]        --
# │    └─Bottleneck: 2-30                  [100, 512, 20, 20]        [100, 512, 20, 20]        --
# │    │    └─Conv2d: 3-187                [100, 512, 20, 20]        [100, 128, 20, 20]        [1, 1]
# │    │    └─BatchNorm2d: 3-188           [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─ReLU: 3-189                  [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─Conv2d: 3-190                [100, 128, 20, 20]        [100, 128, 20, 20]        [3, 3]
# │    │    └─BatchNorm2d: 3-191           [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─ReLU: 3-192                  [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─Conv2d: 3-193                [100, 128, 20, 20]        [100, 512, 20, 20]        [1, 1]
# │    │    └─BatchNorm2d: 3-194           [100, 512, 20, 20]        [100, 512, 20, 20]        --
# │    │    └─ReLU: 3-195                  [100, 512, 20, 20]        [100, 512, 20, 20]        --
# │    └─Bottleneck: 2-31                  [100, 512, 20, 20]        [100, 512, 20, 20]        --
# │    │    └─Conv2d: 3-196                [100, 512, 20, 20]        [100, 128, 20, 20]        [1, 1]
# │    │    └─BatchNorm2d: 3-197           [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─ReLU: 3-198                  [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─Conv2d: 3-199                [100, 128, 20, 20]        [100, 128, 20, 20]        [3, 3]
# │    │    └─BatchNorm2d: 3-200           [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─ReLU: 3-201                  [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─Conv2d: 3-202                [100, 128, 20, 20]        [100, 512, 20, 20]        [1, 1]
# │    │    └─BatchNorm2d: 3-203           [100, 512, 20, 20]        [100, 512, 20, 20]        --
# │    │    └─ReLU: 3-204                  [100, 512, 20, 20]        [100, 512, 20, 20]        --
# │    └─Bottleneck: 2-32                  [100, 512, 20, 20]        [100, 512, 20, 20]        --
# │    │    └─Conv2d: 3-205                [100, 512, 20, 20]        [100, 128, 20, 20]        [1, 1]
# │    │    └─BatchNorm2d: 3-206           [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─ReLU: 3-207                  [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─Conv2d: 3-208                [100, 128, 20, 20]        [100, 128, 20, 20]        [3, 3]
# │    │    └─BatchNorm2d: 3-209           [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─ReLU: 3-210                  [100, 128, 20, 20]        [100, 128, 20, 20]        --
# │    │    └─Conv2d: 3-211                [100, 128, 20, 20]        [100, 512, 20, 20]        [1, 1]
# │    │    └─BatchNorm2d: 3-212           [100, 512, 20, 20]        [100, 512, 20, 20]        --
# │    │    └─ReLU: 3-213                  [100, 512, 20, 20]        [100, 512, 20, 20]        --
# ├─Sequential: 1-17                       [100, 512, 20, 20]        [100, 1024, 10, 10]       --
# │    └─Bottleneck: 2-33                  [100, 512, 20, 20]        [100, 1024, 10, 10]       --
# │    │    └─Conv2d: 3-214                [100, 512, 20, 20]        [100, 256, 20, 20]        [1, 1]
# │    │    └─BatchNorm2d: 3-215           [100, 256, 20, 20]        [100, 256, 20, 20]        --
# │    │    └─ReLU: 3-216                  [100, 256, 20, 20]        [100, 256, 20, 20]        --
# │    │    └─Conv2d: 3-217                [100, 256, 20, 20]        [100, 256, 10, 10]        [3, 3]
# │    │    └─BatchNorm2d: 3-218           [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─ReLU: 3-219                  [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─Conv2d: 3-220                [100, 256, 10, 10]        [100, 1024, 10, 10]       [1, 1]
# │    │    └─BatchNorm2d: 3-221           [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    │    └─Sequential: 3-222            [100, 512, 20, 20]        [100, 1024, 10, 10]       --
# │    │    └─ReLU: 3-223                  [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    └─Bottleneck: 2-34                  [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    │    └─Conv2d: 3-224                [100, 1024, 10, 10]       [100, 256, 10, 10]        [1, 1]
# │    │    └─BatchNorm2d: 3-225           [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─ReLU: 3-226                  [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─Conv2d: 3-227                [100, 256, 10, 10]        [100, 256, 10, 10]        [3, 3]
# │    │    └─BatchNorm2d: 3-228           [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─ReLU: 3-229                  [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─Conv2d: 3-230                [100, 256, 10, 10]        [100, 1024, 10, 10]       [1, 1]
# │    │    └─BatchNorm2d: 3-231           [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    │    └─ReLU: 3-232                  [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    └─Bottleneck: 2-35                  [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    │    └─Conv2d: 3-233                [100, 1024, 10, 10]       [100, 256, 10, 10]        [1, 1]
# │    │    └─BatchNorm2d: 3-234           [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─ReLU: 3-235                  [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─Conv2d: 3-236                [100, 256, 10, 10]        [100, 256, 10, 10]        [3, 3]
# │    │    └─BatchNorm2d: 3-237           [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─ReLU: 3-238                  [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─Conv2d: 3-239                [100, 256, 10, 10]        [100, 1024, 10, 10]       [1, 1]
# │    │    └─BatchNorm2d: 3-240           [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    │    └─ReLU: 3-241                  [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    └─Bottleneck: 2-36                  [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    │    └─Conv2d: 3-242                [100, 1024, 10, 10]       [100, 256, 10, 10]        [1, 1]
# │    │    └─BatchNorm2d: 3-243           [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─ReLU: 3-244                  [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─Conv2d: 3-245                [100, 256, 10, 10]        [100, 256, 10, 10]        [3, 3]
# │    │    └─BatchNorm2d: 3-246           [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─ReLU: 3-247                  [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─Conv2d: 3-248                [100, 256, 10, 10]        [100, 1024, 10, 10]       [1, 1]
# │    │    └─BatchNorm2d: 3-249           [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    │    └─ReLU: 3-250                  [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    └─Bottleneck: 2-37                  [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    │    └─Conv2d: 3-251                [100, 1024, 10, 10]       [100, 256, 10, 10]        [1, 1]
# │    │    └─BatchNorm2d: 3-252           [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─ReLU: 3-253                  [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─Conv2d: 3-254                [100, 256, 10, 10]        [100, 256, 10, 10]        [3, 3]
# │    │    └─BatchNorm2d: 3-255           [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─ReLU: 3-256                  [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─Conv2d: 3-257                [100, 256, 10, 10]        [100, 1024, 10, 10]       [1, 1]
# │    │    └─BatchNorm2d: 3-258           [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    │    └─ReLU: 3-259                  [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    └─Bottleneck: 2-38                  [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    │    └─Conv2d: 3-260                [100, 1024, 10, 10]       [100, 256, 10, 10]        [1, 1]
# │    │    └─BatchNorm2d: 3-261           [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─ReLU: 3-262                  [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─Conv2d: 3-263                [100, 256, 10, 10]        [100, 256, 10, 10]        [3, 3]
# │    │    └─BatchNorm2d: 3-264           [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─ReLU: 3-265                  [100, 256, 10, 10]        [100, 256, 10, 10]        --
# │    │    └─Conv2d: 3-266                [100, 256, 10, 10]        [100, 1024, 10, 10]       [1, 1]
# │    │    └─BatchNorm2d: 3-267           [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# │    │    └─ReLU: 3-268                  [100, 1024, 10, 10]       [100, 1024, 10, 10]       --
# ├─Sequential: 1-18                       [100, 1024, 10, 10]       [100, 2048, 5, 5]         --
# │    └─Bottleneck: 2-39                  [100, 1024, 10, 10]       [100, 2048, 5, 5]         --
# │    │    └─Conv2d: 3-269                [100, 1024, 10, 10]       [100, 512, 10, 10]        [1, 1]
# │    │    └─BatchNorm2d: 3-270           [100, 512, 10, 10]        [100, 512, 10, 10]        --
# │    │    └─ReLU: 3-271                  [100, 512, 10, 10]        [100, 512, 10, 10]        --
# │    │    └─Conv2d: 3-272                [100, 512, 10, 10]        [100, 512, 5, 5]          [3, 3]
# │    │    └─BatchNorm2d: 3-273           [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    │    └─ReLU: 3-274                  [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    │    └─Conv2d: 3-275                [100, 512, 5, 5]          [100, 2048, 5, 5]         [1, 1]
# │    │    └─BatchNorm2d: 3-276           [100, 2048, 5, 5]         [100, 2048, 5, 5]         --
# │    │    └─Sequential: 3-277            [100, 1024, 10, 10]       [100, 2048, 5, 5]         --
# │    │    └─ReLU: 3-278                  [100, 2048, 5, 5]         [100, 2048, 5, 5]         --
# │    └─Bottleneck: 2-40                  [100, 2048, 5, 5]         [100, 2048, 5, 5]         --
# │    │    └─Conv2d: 3-279                [100, 2048, 5, 5]         [100, 512, 5, 5]          [1, 1]
# │    │    └─BatchNorm2d: 3-280           [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    │    └─ReLU: 3-281                  [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    │    └─Conv2d: 3-282                [100, 512, 5, 5]          [100, 512, 5, 5]          [3, 3]
# │    │    └─BatchNorm2d: 3-283           [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    │    └─ReLU: 3-284                  [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    │    └─Conv2d: 3-285                [100, 512, 5, 5]          [100, 2048, 5, 5]         [1, 1]
# │    │    └─BatchNorm2d: 3-286           [100, 2048, 5, 5]         [100, 2048, 5, 5]         --
# │    │    └─ReLU: 3-287                  [100, 2048, 5, 5]         [100, 2048, 5, 5]         --
# │    └─Bottleneck: 2-41                  [100, 2048, 5, 5]         [100, 2048, 5, 5]         --
# │    │    └─Conv2d: 3-288                [100, 2048, 5, 5]         [100, 512, 5, 5]          [1, 1]
# │    │    └─BatchNorm2d: 3-289           [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    │    └─ReLU: 3-290                  [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    │    └─Conv2d: 3-291                [100, 512, 5, 5]          [100, 512, 5, 5]          [3, 3]
# │    │    └─BatchNorm2d: 3-292           [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    │    └─ReLU: 3-293                  [100, 512, 5, 5]          [100, 512, 5, 5]          --
# │    │    └─Conv2d: 3-294                [100, 512, 5, 5]          [100, 2048, 5, 5]         [1, 1]
# │    │    └─BatchNorm2d: 3-295           [100, 2048, 5, 5]         [100, 2048, 5, 5]         --
# │    │    └─ReLU: 3-296                  [100, 2048, 5, 5]         [100, 2048, 5, 5]         --
# ├─AdaptiveAvgPool2d: 1-19                [100, 2048, 5, 5]         [100, 2048, 1, 1]         --
# ├─Sequential: 1-20                       [100, 2048]               [100, 2]                  --
# │    └─Linear: 2-42                      [100, 2048]               [100, 512]                --
# │    └─Tanh: 2-43                        [100, 512]                [100, 512]                --
# │    └─Linear: 2-44                      [100, 512]                [100, 512]                --
# │    └─Tanh: 2-45                        [100, 512]                [100, 512]                --
# │    └─Linear: 2-46                      [100, 512]                [100, 64]                 --
# │    └─Tanh: 2-47                        [100, 64]                 [100, 64]                 --
# │    └─Linear: 2-48                      [100, 64]                 [100, 64]                 --
# │    └─Tanh: 2-49                        [100, 64]                 [100, 64]                 --
# │    └─Linear: 2-50                      [100, 64]                 [100, 2]                  --
# ===================================================================================================================
# Total params: 24,856,898
# Trainable params: 24,856,898
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 417.34
# ===================================================================================================================
# Input size (MB): 30.72
# Forward/backward pass size (MB): 18147.13
# Params size (MB): 99.43
# Estimated Total Size (MB): 18277.27
# ===================================================================================================================
