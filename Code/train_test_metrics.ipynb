# %% [markdown]
# ## Model metrics

# %%
import pandas as pd
import numpy as np
from metrics_utils import *
from  matplotlib.colors import LinearSegmentedColormap
# Out:
# GZDESI/GZRings/GZCD not available from galaxy_datasets.pytorch.datasets - skipping

# %%
LOG_PATH = "lightning_logs"
METRICS_PATH = "../Metrics"

# %% [markdown]
# ## Training metrics - image rotation in training

# %%
repeat_model_ids = ['g_lenet_cut_dataset_60',
             'lenet_cut_dataset_60',
             'resnet18_cut_dataset',
             'resnet50_cut_dataset', 
             'ce_resnet50_cut_dataset',
             'g_resnet18_cut_dataset',
             'g_resnet50_cut_dataset']

# %%
repeat_metrics = get_results_runs(repeat_model_ids,'val',METRICS_PATH)
repeat_metrics.head(9)
# Out:
# g_lenet_cut_dataset_60: Removed 5 NaNs
# lenet_cut_dataset_60: Removed 5 NaNs
# Model                   Loss        Accuracy
# g_lenet_60   0.9028 ± 0.0070  64.32% ± 0.78%
# lenet_60     0.9195 ± 0.0021  62.79% ± 0.20%
# resnet18     0.6216 ± 0.0007  84.31% ± 0.17%
# resnet50     0.6229 ± 0.0016  83.71% ± 0.40%
# ce_resnet50  0.6152 ± 0.0009  84.57% ± 0.20%
# g_resnet18   0.5676 ± 0.0012  92.86% ± 0.25%
# g_resnet50   0.5636 ± 0.0015  93.36% ± 0.39%

# %%
repeat_metrics = get_results_runs(repeat_model_ids,'test',METRICS_PATH)
repeat_metrics.head(9)
# Out:
# g_lenet_cut_dataset_60: Removed 5 NaNs
# lenet_cut_dataset_60: Removed 5 NaNs
# Model                   Loss        Accuracy              ECE           C Viol
# g_lenet_60   0.4899 ± 0.0130  91.80% ± 0.15%  0.1840 ± 0.0115  0.0000 ± 0.0000
# lenet_60     0.5280 ± 0.0052  91.25% ± 0.10%  0.2113 ± 0.0046  0.0000 ± 0.0000
# resnet18     0.3850 ± 0.0013  94.64% ± 0.09%  0.1272 ± 0.0028  0.2137 ± 0.2867
# resnet50     0.3890 ± 0.0030  94.46% ± 0.22%  0.1264 ± 0.0018  0.2507 ± 0.2260
# ce_resnet50  0.3777 ± 0.0022  95.07% ± 0.13%  0.1270 ± 0.0020  0.0478 ± 0.0238
# g_resnet18   0.3775 ± 0.0019  94.51% ± 0.16%  0.1078 ± 0.0028  0.4058 ± 0.1645
# g_resnet50   0.3820 ± 0.0025  94.43% ± 0.14%  0.1090 ± 0.0059  0.0264 ± 0.3225

# %% [markdown]
# ## Training metrics - no image rotation in training

# %%
no_rotate_repeat_model_ids = ['g_lenet_cut_dataset_60_nr',
             'lenet_cut_dataset_60_nr',
             'resnet18_cut_dataset_60_nr', 
             'resnet50_cut_dataset_60_nr', 
             'ce_resnet50_cut_dataset_60_nr', 
             'g_resnet18_cut_dataset_60_nr',
             'g_resnet50_cut_dataset_60_nr']

# %%
repeat_metrics = get_results_runs(no_rotate_repeat_model_ids,'val',METRICS_PATH)
repeat_metrics.head(9)
# Out:
# lenet_cut_dataset_60_nr: Removed 4 NaNs
# Model                         Loss        Accuracy              ECE  \
# g_lenet_60_nr      0.7821 ± 0.0351  77.54% ± 2.58%  0.1587 ± 0.0089
# lenet_60_nr        0.8562 ± 0.0341  70.61% ± 3.42%  0.1421 ± 0.0146
# resnet18_60_nr     0.5290 ± 0.0003  98.16% ± 0.12%  0.2273 ± 0.0023
# resnet50_60_nr     0.5309 ± 0.0002  97.40% ± 0.13%  0.2195 ± 0.0031
# ce_resnet50_60_nr  0.5310 ± 0.0034  97.65% ± 0.82%  0.2232 ± 0.0066
# g_resnet18_60_nr   0.5324 ± 0.0004  98.04% ± 0.32%  0.2285 ± 0.0041
# g_resnet50_60_nr   0.5329 ± 0.0005  97.83% ± 0.29%  0.2250 ± 0.0048
#
# Model                        C Viol
# g_lenet_60_nr       0.4174 ± 0.2577
# lenet_60_nr        -0.6823 ± 0.0000
# resnet18_60_nr      0.4963 ± 0.1710
# resnet50_60_nr      0.7647 ± 0.3068
# ce_resnet50_60_nr   0.2887 ± 0.0618
# g_resnet18_60_nr   -0.3925 ± 0.1478
# g_resnet50_60_nr    0.2535 ± 0.1361

# %%
repeat_metrics = get_results_runs(no_rotate_repeat_model_ids,'test',METRICS_PATH,print_latex=False)
repeat_metrics.head(9)
# Out:
# g_lenet_cut_dataset_60_nr: Removed 4 NaNs
# lenet_cut_dataset_60_nr: Removed 5 NaNs
# resnet18_cut_dataset_60_nr: Removed 1 NaNs
# resnet50_cut_dataset_60_nr: Removed 1 NaNs
# g_resnet18_cut_dataset_60_nr: Removed 1 NaNs
# Model                         Loss        Accuracy              ECE  \
# g_lenet_60_nr      0.5098 ± 0.0087  89.53% ± 0.28%  0.1545 ± 0.0085
# lenet_60_nr        0.5192 ± 0.0095  89.60% ± 0.60%  0.1797 ± 0.0121
# resnet18_60_nr     0.4514 ± 0.0075  92.18% ± 0.29%  0.1109 ± 0.0040
# resnet50_60_nr     0.4579 ± 0.0077  92.32% ± 0.37%  0.1201 ± 0.0060
# ce_resnet50_60_nr  0.4075 ± 0.0023  94.27% ± 0.06%  0.1171 ± 0.0063
# g_resnet18_60_nr   0.4119 ± 0.0298  93.33% ± 1.10%  0.1053 ± 0.0082
# g_resnet50_60_nr   0.4215 ± 0.0136  93.39% ± 0.83%  0.1254 ± 0.0069
#
# Model                        C Viol
# g_lenet_60_nr       0.1405 ± 0.0000
# lenet_60_nr         0.0000 ± 0.0000
# resnet18_60_nr      0.9351 ± 0.3880
# resnet50_60_nr      1.3171 ± 0.4113
# ce_resnet50_60_nr   0.0117 ± 0.0550
# g_resnet18_60_nr    0.7135 ± 0.3542
# g_resnet50_60_nr   -0.1103 ± 0.2283

# %% [markdown]
# ## Testing metrics - custom 2 class predict function

# %%
c_repeat_model_ids = ['ce_resnet50_cut_dataset',
             'g_resnet18_cut_dataset_c',
             'g_resnet50_cut_dataset_c']

# %%
repeat_metrics = get_results_runs(c_repeat_model_ids,'val',METRICS_PATH)
repeat_metrics.head(9)
# Out:
# Model                    Loss        Accuracy              ECE  \
# ce_resnet50   0.6152 ± 0.0009  84.57% ± 0.20%  0.1434 ± 0.0011
# g_resnet18_c  0.5692 ± 0.0012  92.76% ± 0.21%  0.1899 ± 0.0018
# g_resnet50_c  0.5606 ± 0.0032  93.73% ± 0.50%  0.2021 ± 0.0044
#
# Model                   C Viol
# ce_resnet50   -0.0337 ± 0.0325
# g_resnet18_c  -0.0188 ± 0.0374
# g_resnet50_c   0.0091 ± 0.0293

# %%
repeat_metrics = get_results_runs(c_repeat_model_ids,'test',METRICS_PATH)
repeat_metrics.head(9)
# Out:
# g_resnet50_cut_dataset_c: Removed 1 NaNs
# Model                    Loss        Accuracy              ECE  \
# ce_resnet50   0.3777 ± 0.0022  95.07% ± 0.13%  0.1270 ± 0.0020
# g_resnet18_c  0.3766 ± 0.0045  94.40% ± 0.32%  0.1094 ± 0.0046
# g_resnet50_c  0.3805 ± 0.0042  94.42% ± 0.24%  0.1158 ± 0.0076
#
# Model                  C Viol
# ce_resnet50   0.0478 ± 0.0238
# g_resnet18_c  0.0331 ± 0.0076
# g_resnet50_c  0.0561 ± 0.0142

# %% [markdown]
# ## Adding dropout to CE-Resnet50

# %%
dropout_ids = ['ce_resnet50_cut_dataset_60_dropout','ce_resnet50_cut_dataset']

# %%
repeat_metrics = get_results_runs(dropout_ids,'val',METRICS_PATH,max_runs=3)
repeat_metrics.head(9)
# Out:
# Model                              Loss        Accuracy
# ce_resnet50_60_dropout  0.6295 ± 0.0008  82.83% ± 0.02%
# ce_resnet50             0.6153 ± 0.0009  84.57% ± 0.20%

# %%
repeat_metrics = get_results_runs(dropout_ids,'test',METRICS_PATH,max_runs=3)
repeat_metrics.head(9)
# Out:
# Model                              Loss        Accuracy
# ce_resnet50_60_dropout  0.3867 ± 0.0102  94.67% ± 0.63%
# ce_resnet50             0.3776 ± 0.0029  95.09% ± 0.16%

# %%
repeat_metrics = get_results_runs(['ce_resnet50_cut_dataset'],'test',METRICS_PATH,max_runs=5,custom_save_id='_dropout')
repeat_metrics.head(9)
# Out:
# Model                   Loss        Accuracy
# ce_resnet50  0.3780 ± 0.0021  95.07% ± 0.11%

# %% [markdown]
# ## Test metrics - all models

# %%
all_models = ['lenet_cut_dataset_60',
             'g_lenet_cut_dataset_60',
             'resnet18_cut_dataset',
             'resnet50_cut_dataset',
             'ce_resnet50_cut_dataset',
             'g_resnet18_cut_dataset',
             'g_resnet50_cut_dataset',

             'g_lenet_cut_dataset_60_nr',
             'lenet_cut_dataset_60_nr',
             'resnet18_cut_dataset_60_nr',
             'resnet50_cut_dataset_60_nr',
             'ce_resnet50_cut_dataset_60_nr',
             'g_resnet18_cut_dataset_60_nr',
             'g_resnet50_cut_dataset_60_nr',

             'g_resnet18_cut_dataset_c',
             'g_resnet50_cut_dataset_c']
repeat_metrics = get_results_runs(all_models,'test',METRICS_PATH)
repeat_metrics.sort_values('Accuracy',ascending=False).head(len(all_models))
# Out:
# lenet_cut_dataset_60: Removed 5 NaNs
# g_lenet_cut_dataset_60: Removed 5 NaNs
# g_lenet_cut_dataset_60_nr: Removed 4 NaNs
# lenet_cut_dataset_60_nr: Removed 5 NaNs
# resnet18_cut_dataset_60_nr: Removed 1 NaNs
# resnet50_cut_dataset_60_nr: Removed 1 NaNs
# g_resnet18_cut_dataset_60_nr: Removed 1 NaNs
# g_resnet50_cut_dataset_c: Removed 1 NaNs
# Model                         Loss        Accuracy              ECE  \
# ce_resnet50        0.3777 ± 0.0022  95.07% ± 0.13%  0.1270 ± 0.0020
# resnet18           0.3850 ± 0.0013  94.64% ± 0.09%  0.1272 ± 0.0028
# g_resnet18         0.3775 ± 0.0019  94.51% ± 0.16%  0.1078 ± 0.0028
# resnet50           0.3890 ± 0.0030  94.46% ± 0.22%  0.1264 ± 0.0018
# g_resnet50         0.3820 ± 0.0025  94.43% ± 0.14%  0.1090 ± 0.0059
# g_resnet50_c       0.3805 ± 0.0042  94.42% ± 0.24%  0.1158 ± 0.0076
# g_resnet18_c       0.3766 ± 0.0045  94.40% ± 0.32%  0.1094 ± 0.0046
# ce_resnet50_60_nr  0.4075 ± 0.0023  94.27% ± 0.06%  0.1171 ± 0.0063
# g_resnet50_60_nr   0.4215 ± 0.0136  93.39% ± 0.83%  0.1254 ± 0.0069
# g_resnet18_60_nr   0.4119 ± 0.0298  93.33% ± 1.10%  0.1053 ± 0.0082
# resnet50_60_nr     0.4579 ± 0.0077  92.32% ± 0.37%  0.1201 ± 0.0060
# resnet18_60_nr     0.4514 ± 0.0075  92.18% ± 0.29%  0.1109 ± 0.0040
# g_lenet_60         0.4899 ± 0.0130  91.80% ± 0.15%  0.1840 ± 0.0115
# lenet_60           0.5280 ± 0.0052  91.25% ± 0.10%  0.2113 ± 0.0046
# lenet_60_nr        0.5192 ± 0.0095  89.60% ± 0.60%  0.1797 ± 0.0121
# g_lenet_60_nr      0.5098 ± 0.0087  89.53% ± 0.28%  0.1545 ± 0.0085
#
# Model                        C Viol
# ce_resnet50         0.0478 ± 0.0238
# resnet18            0.2137 ± 0.2867
# g_resnet18          0.4058 ± 0.1645
# resnet50            0.2507 ± 0.2260
# g_resnet50          0.0264 ± 0.3225
# g_resnet50_c        0.0561 ± 0.0142
# g_resnet18_c        0.0331 ± 0.0076
# ce_resnet50_60_nr   0.0117 ± 0.0550
# g_resnet50_60_nr   -0.1103 ± 0.2283
# g_resnet18_60_nr    0.7135 ± 0.3542
# resnet50_60_nr      1.3171 ± 0.4113
# resnet18_60_nr      0.9351 ± 0.3880
# g_lenet_60          0.0000 ± 0.0000
# lenet_60            0.0000 ± 0.0000
# lenet_60_nr         0.0000 ± 0.0000
# g_lenet_60_nr       0.1405 ± 0.0000

# %% [markdown]
# ## Final models

# %%
all_models = ['lenet_cut_dataset_60',
             'g_lenet_cut_dataset_60',
             'resnet18_cut_dataset',
             'resnet50_cut_dataset',
             'ce_resnet50_cut_dataset',
             'g_resnet18_cut_dataset',
             'g_resnet50_cut_dataset',
             'g_resnet18_cut_dataset_c',
             'g_resnet50_cut_dataset_c']
repeat_metrics = get_results_runs(all_models,'test',METRICS_PATH,print_latex=False)
repeat_metrics.sort_values('Accuracy',ascending=False).head(len(all_models))
# Out:
# lenet_cut_dataset_60: Removed 5 NaNs
# g_lenet_cut_dataset_60: Removed 5 NaNs
# g_resnet50_cut_dataset_c: Removed 1 NaNs
# Model                    Loss        Accuracy              ECE  \
# ce_resnet50   0.3777 ± 0.0022  95.07% ± 0.13%  0.1270 ± 0.0020
# resnet18      0.3850 ± 0.0013  94.64% ± 0.09%  0.1272 ± 0.0028
# g_resnet18    0.3775 ± 0.0019  94.51% ± 0.16%  0.1078 ± 0.0028
# resnet50      0.3890 ± 0.0030  94.46% ± 0.22%  0.1264 ± 0.0018
# g_resnet50    0.3820 ± 0.0025  94.43% ± 0.14%  0.1090 ± 0.0059
# g_resnet50_c  0.3805 ± 0.0042  94.42% ± 0.24%  0.1158 ± 0.0076
# g_resnet18_c  0.3766 ± 0.0045  94.40% ± 0.32%  0.1094 ± 0.0046
# g_lenet_60    0.4899 ± 0.0130  91.80% ± 0.15%  0.1840 ± 0.0115
# lenet_60      0.5280 ± 0.0052  91.25% ± 0.10%  0.2113 ± 0.0046
#
# Model                  C Viol
# ce_resnet50   0.0478 ± 0.0238
# resnet18      0.2137 ± 0.2867
# g_resnet18    0.4058 ± 0.1645
# resnet50      0.2507 ± 0.2260
# g_resnet50    0.0264 ± 0.3225
# g_resnet50_c  0.0561 ± 0.0142
# g_resnet18_c  0.0331 ± 0.0076
# g_lenet_60    0.0000 ± 0.0000
# lenet_60      0.0000 ± 0.0000

# %% [markdown]
# ## Validation accuracy and loss graphs (default models)

# %%
#plot_combined_metrics_run(repeat_model_ids,'val_loss','Validation Loss',METRICS_PATH,2)
plot_combined_metrics(repeat_model_ids,'val_acc','Validation Accuracy',METRICS_PATH)

# %%
plot_combined_metrics(repeat_model_ids,'val_loss','Validation Loss',METRICS_PATH,l_loc="upper right")
